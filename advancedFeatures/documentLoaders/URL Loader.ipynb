# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://github.com/Princekrampah/langChain/blob/master/README.md")

# %%
loader.load()
# Out:
# [Document(page_content='\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nlangChain/README.md at master · Princekrampah/langChain · GitHub\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\nToggle navigation\n\n\n\n\n\n\n\n\n\n\n            Sign\xa0up\n          \n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n        Product\n        \n\n\n\n\n\n\n\n\n\n\n\n\nActions\n        Automate any workflow\n      \n\n\n\n\n\n\n\nPackages\n        Host and manage packages\n      \n\n\n\n\n\n\n\nSecurity\n        Find and fix vulnerabilities\n      \n\n\n\n\n\n\n\nCodespaces\n        Instant dev environments\n      \n\n\n\n\n\n\n\nCopilot\n        Write better code with AI\n      \n\n\n\n\n\n\n\nCode review\n        Manage code changes\n      \n\n\n\n\n\n\n\nIssues\n        Plan and track work\n      \n\n\n\n\n\n\n\nDiscussions\n
# ...

# %%
docs = loader.load()

# %%
print(docs[0].page_content[:500])
# Out:
# langChain/README.md at master · Princekrampah/langChain · GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
# Toggle navigation
#
#
#
#
#
#
#
#
#
#
#             Sign up
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Product
#
#
#
#
#
#
#
#
#
#
#
#
#
# Actions
#         Automate any workflow
#
#
#
#
#
#
#
#
# Packages
#         Host and manage packages
#
#
#
#
#
#
#
#
# Security
#         Find and fix vulnerabilities
#
#
#
#
#
#
#
#
# Codesp
